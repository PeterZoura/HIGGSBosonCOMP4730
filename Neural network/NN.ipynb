# %% [markdown]
# Neural Network Model

# %% [markdown]
# Import necessary libraries and modules for data manipulation,neural network modeling, and visualization.

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
import time
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn import preprocessing

# %% [markdown]
# Load the dataset from the specified file path.

# %%
data = pd.read_csv("../Dataset/higgs10k.csv", index_col=False)
data_encoded = pd.get_dummies(data, drop_first=False)
print(data_encoded)
# Out:
#       process type  lepton  pT  lepton  eta  lepton  phi  \
# 0              1.0    0.748873    -0.874678    -1.194860
# 1              0.0    1.630977     0.634973    -0.305970
# 2              1.0    0.299586     1.489144     0.709529
# 3              1.0    0.455144    -0.117904     1.524621
# 4              1.0    0.540243    -0.597097    -0.997884
# ...            ...         ...          ...          ...
# 9995           1.0    0.774678     1.220329     1.540712
# 9996           1.0    1.155702     0.395377    -0.800909
# 9997           0.0    1.578819     1.777439    -0.199436
# 9998           0.0    0.348449     2.227412    -0.784263
# 9999           0.0    0.503824    -0.240624     0.396588
#
#       missing energy magnitude  missing energy phi  jet 1 pt  jet 1 eta  \
# 0                     0.766419           -0.553490  0.394003   1.605137
# 1                     0.215144           -0.452114  0.550285   0.697096
# 2                     1.582114           -1.352004  0.734232  -0.526828
# 3                     0.991996           -0.172513  2.414858  -1.634895
# 4                     0.668254            0.995326  0.583172  -0.925890
# ...                        ...                 ...       ...        ...
# 9995                  1.029400           -0.634221  0.615417   0.325760
# 9996                  1.621500           -0.296107  0.516298  -0.490189
# 9997                  0.843990           -0.760235  1.127960   1.441749
# 9998                  1.844288            1.111028  0.932836   0.570347
# 9999                  0.889164           -1.459847  0.853596   0.548562
#
#       jet 1 phi  jet 1 b-tag  ...  jet 4 eta  jet 4 phi  jet 4 b-tag  \
# 0      0.657096     0.000000  ...  -1.674435   0.156879     0.000000
# 1     -1.597100     2.173076  ...  -0.483498   0.347214     3.101961
# 2     -0.915218     2.173076  ...   0.513391  -0.156194     3.101961
# 3     -1.567163     0.000000  ...  -0.092071   0.211815     0.000000
# 4      0.781276     0.000000  ...  -2.221600   0.083630     0.000000
# ...         ...          ...  ...        ...        ...          ...
# 9995   1.526356     0.000000  ...   1.466974  -1.671662     0.000000
# 9996   0.881618     2.173076  ...  -0.287785  -1.394206     3.101961
# 9997   1.186524     2.173076  ...   2.170709   0.493155     0.000000
# 9998  -0.349198     2.173076  ...  -0.822457   0.768392     3.101961
# 9999   0.755774     0.000000  ...   1.977495  -0.388148     0.000000
#
#           m_jj     m_jjj      m_lv     m_jlv      m_bb     m_wbb    m_wwbb
# 0     0.815718  1.086726  0.982625  0.899206  0.883548  0.895692  1.079946
# 1     0.891039  1.010851  1.000828  0.976172  1.038880  0.830898  0.928035
# 2     0.801086  0.840556  0.989608  0.936557  0.790547  1.232777  1.026098
# 3     0.773106  0.937234  0.984253  0.675838  1.881146  1.067955  0.848495
# 4     1.079204  1.113606  0.986507  1.033303  0.912932  0.866989  0.857450
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.979970  1.124954  1.145046  1.231963  0.909005  0.984893  0.903041
# 9996  1.083132  1.392422  0.984439  1.042288  0.842495  1.086328  1.022021
# 9997  0.537190  0.658713  1.000550  1.435993  1.196724  1.074618  0.814133
# 9998  1.375095  1.456105  1.100103  2.466959  1.601059  1.793594  1.572835
# 9999  0.865462  1.530217  0.988251  0.751569  1.104844  1.269781  1.013316
#
# [10000 rows x 29 columns]

# %% [markdown]
# Extract the target variable 'process type' and store it as 'y'. The rest of the data columns, excluding 'process type', are stored as 'x'. Then, the data is split into training and testing sets using an 80-20 split.

# %%
y = (data_encoded['process type']).values
x = (data_encoded.drop(columns=['process type'])).values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %% [markdown]
# Use the StandardScaler to normalize the data to have mean=0 and variance=1 for better performance during modeling.

# %%
scaler = preprocessing.StandardScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# Define the neural network model and set hyperparameters for tuning. In this case, we're using the MLPClassifier with a maximum of 1000 iterations, and early stopping enabled.

# %%
nn = MLPClassifier(max_iter=1000, random_state=1, early_stopping=True)
parameter_space = {
    'hidden_layer_sizes': [(100, 50, 30), (20,), (5, 2), (100, 50), (50, 30, 20)],
    'activation': ['tanh', 'relu', 'logistic'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.001, 0.005, 0.01, 0.05],
    'learning_rate': ['constant', 'adaptive'],
}

# %% [markdown]
# Use GridSearchCV to search for the best hyperparameter by performing cross-validation on the training set.

# %%
# Measure time for training
start_time = time.time()

clf = GridSearchCV(nn, parameter_space, n_jobs=-1, cv=10)
clf.fit(x_train, y_train)

# Training time
elapsed_time = time.time() - start_time
print(f"Training completed in {elapsed_time:.2f} seconds")
# Out:
# Training completed in 2244.89 seconds

# %% [markdown]
# Display the best hyperparameters obtained from the GridSearchCV.

# %%
print('Best parameters found:\n', clf.best_params_)
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.667 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.667 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.636 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.636 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.620 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.620 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.623 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.649 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.650 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.650 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.622 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.666 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.666 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.635 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.635 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.620 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.620 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.623 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.649 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.647 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.622 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.668 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.668 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.636 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.599 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.636 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.620 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.620 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.623 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.649 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.614 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.647 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.623 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.666 (+/-0.059) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.666 (+/-0.059) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.600 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.636 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.600 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.636 (+/-0.042) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.620 (+/-0.052) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.519 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.620 (+/-0.052) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.622 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.650 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.623 (+/-0.048) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.650 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.614 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.647 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.623 (+/-0.045) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.667 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.624 (+/-0.047) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.667 (+/-0.055) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.603 (+/-0.029) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.636 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.603 (+/-0.030) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.636 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.519 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.621 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.519 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.621 (+/-0.054) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.622 (+/-0.051) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.649 (+/-0.040) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.626 (+/-0.040) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.040) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.653 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.614 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.653 (+/-0.039) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.602 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.646 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.609 (+/-0.031) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.646 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.588 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.657 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.597 (+/-0.028) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.657 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.613 (+/-0.036) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.663 (+/-0.031) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.663 (+/-0.031) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.603 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.644 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.603 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.644 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.602 (+/-0.039) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.041) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.607 (+/-0.034) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.647 (+/-0.041) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.588 (+/-0.045) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.656 (+/-0.042) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.597 (+/-0.028) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.656 (+/-0.042) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.614 (+/-0.037) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.661 (+/-0.032) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.035) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.661 (+/-0.032) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.603 (+/-0.028) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.647 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.603 (+/-0.028) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.647 (+/-0.029) for {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.601 (+/-0.041) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.645 (+/-0.042) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.605 (+/-0.037) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.645 (+/-0.042) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.590 (+/-0.048) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.655 (+/-0.035) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.599 (+/-0.031) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.655 (+/-0.035) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.613 (+/-0.036) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.662 (+/-0.037) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.615 (+/-0.034) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.662 (+/-0.037) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.603 (+/-0.027) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.646 (+/-0.025) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.603 (+/-0.027) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.646 (+/-0.025) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.606 (+/-0.039) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.043) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.611 (+/-0.033) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.648 (+/-0.043) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.590 (+/-0.048) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.658 (+/-0.043) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.599 (+/-0.031) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.658 (+/-0.043) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.613 (+/-0.038) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.658 (+/-0.037) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.035) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.658 (+/-0.037) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.603 (+/-0.028) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.036) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.604 (+/-0.032) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.648 (+/-0.036) for {'activation': 'relu', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.606 (+/-0.037) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.649 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.610 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.649 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.586 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.655 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.597 (+/-0.026) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.655 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.615 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.661 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.617 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.661 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.604 (+/-0.032) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.033) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.604 (+/-0.032) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.648 (+/-0.033) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.629 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.629 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.562 (+/-0.027) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.621 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.564 (+/-0.023) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.621 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.632 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.632 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.047) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.648 (+/-0.047) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.630 (+/-0.046) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.630 (+/-0.046) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.562 (+/-0.027) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.621 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.564 (+/-0.023) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.621 (+/-0.049) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.633 (+/-0.041) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.633 (+/-0.041) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.639 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.639 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.001, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.629 (+/-0.039) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.629 (+/-0.039) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.563 (+/-0.027) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.625 (+/-0.036) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.565 (+/-0.024) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.625 (+/-0.036) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.634 (+/-0.046) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.634 (+/-0.046) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.641 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.641 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.005, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.629 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.629 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.563 (+/-0.027) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.624 (+/-0.044) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.565 (+/-0.024) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.624 (+/-0.044) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.637 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.637 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.640 (+/-0.042) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.640 (+/-0.042) for {'activation': 'logistic', 'alpha': 0.01, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.628 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.628 (+/-0.045) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50, 30), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.566 (+/-0.032) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.626 (+/-0.047) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.567 (+/-0.028) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.626 (+/-0.047) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (5, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.638 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.638 (+/-0.040) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.638 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.529 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.638 (+/-0.043) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 30, 20), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %% [markdown]
# Use the trained model to make predictions on the test set and print a classification report and accuracy score.

# %%
y_true, y_pred = y_test, clf.predict(x_test)
print('Results on the test set:')
print(classification_report(y_true, y_pred))
print('Accuracy: ', clf.score(x_test, y_test))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.62      0.64       950
#          1.0       0.67      0.69      0.68      1050
#
#     accuracy                           0.66      2000
#    macro avg       0.66      0.66      0.66      2000
# weighted avg       0.66      0.66      0.66      2000
#
# Accuracy:  0.6605

# %% [markdown]
# Plot a confusion matrix to visualize the performance of the model on different classes in the test set.

# %%
fig = plot_confusion_matrix(clf, x_test, y_test, display_labels=clf.classes_)
fig.figure_.suptitle("Confusion Matrix")
plt.show()
